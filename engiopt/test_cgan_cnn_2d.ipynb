# %%
"""Evaluation for the CGAN 2D w/ CNN."""

from __future__ import annotations
import os
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"

from engiopt import metrics
from engibench.utils.all_problems import BUILTIN_PROBLEMS
import torch as th

from engiopt.cgan_cnn_2d import Generator
import wandb
import numpy as np




#problem_id: str = "beams2d"
problem_id: str = "heatconduction2d"
"""Problem identifier."""
seed: int = 1
"""Random seed."""
wandb_project: str = "engiopt"
"""Wandb project name."""
wandb_entity: str | None = None
"""Wandb entity name."""
n_samples: int = 5
"""Number of generated samples."""
sigma: float = 10
"""Kernel bandwidth."""



problem = BUILTIN_PROBLEMS[problem_id]()
problem.reset(seed=seed)

if th.backends.mps.is_available():
    device = th.device("mps")
elif th.cuda.is_available():
    device = th.device("cuda")
else:
    device = th.device("cpu")

# %%
test_ds = problem.dataset["test"] 

# Extract conditions
condition_keys = [key for key, _ in problem.conditions]
conditions_ds = test_ds.select_columns(condition_keys)

# Sample conditions at random indices
selected_indices = np.random.choice(len(test_ds), n_samples, replace=True)
sampled_conditions = conditions_ds.select(selected_indices)

# Convert dict_values to a list of lists
conditions_list = list(sampled_conditions[:].values())

# Transpose the list to align the data correctly
conditions_list = list(map(list, zip(*conditions_list)))

# Create a tensor from the list
conditions_tensor = th.tensor(conditions_list, dtype=th.float32, device=device)

# Reshape to match the expected input shape for the model
conditions_tensor = conditions_tensor.unsqueeze(-1).unsqueeze(-1)

# %%
# Restores the pytorch model from wandb
if wandb_entity is not None:
    artifact_path = f"{wandb_entity}/{wandb_project}/{problem_id}_cgan_cnn_2d_generator:seed_{seed}"
else:
    artifact_path = f"{wandb_project}/{problem_id}_cgan_cnn_2d_generator:seed_{seed}"

    
api = wandb.Api()
artifact = api.artifact(artifact_path, type="model")
run = artifact.logged_by()
artifact_dir = artifact.download()


ckpt_path = os.path.join(artifact_dir, "generator.pth")
ckpt = th.load(ckpt_path)
model = Generator(latent_dim=run.config["latent_dim"], 
                  n_conds=len(problem.conditions), 
                  design_shape=problem.design_space.shape)
model.load_state_dict(ckpt["generator"])
model.eval()  # Set to evaluation mode
model.to(device)


# Sample noise as generator input
z = th.randn((n_samples, run.config["latent_dim"],1,1), device=device, dtype=th.float)

# Generate a batch of designs
gen_designs = model(z, conditions_tensor)
gen_designs_np = gen_designs.detach().cpu().numpy()
gen_designs_np = gen_designs_np.reshape(n_samples, *problem.design_space.shape)

gen_designs_np = np.clip(gen_designs_np, 1e-3, 1)
# Out:
# wandb:   1 of 1 files downloaded.

# %%
i = 1

# Load/Simulate GAN Warmstart Design
problem.render(gen_designs_np[i])
GAN_opt_design, GAN_opt_history = problem.optimize(gen_designs_np[i], sampled_conditions[i])
problem.render(GAN_opt_design)

# Load/Simulate Dataset Design
problem.render(np.array(test_ds['optimal_design'][selected_indices[i]]))
opt_design, opt_history = problem.optimize(np.array(test_ds['optimal_design'][selected_indices[i]]), sampled_conditions[i])
problem.render(opt_design)

print('Obj_GAN_output:', problem.simulate(gen_designs_np[i]), 'Obj_GAN_optimized:', problem.simulate(opt_design))
print('Obj_Dataset:', problem.simulate(np.array(test_ds['optimal_design'][selected_indices[i]])), 'Obj_Dataset_optimized:', problem.simulate(GAN_opt_design))
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 1.167e-16 (tol = 1.000e-07) r (rel) = 1.178e-12 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
# List of options:
#
#                                     Name   Value                # times used
#                           acceptable_tol = 0.001                     1
#                         file_print_level = 5                         1
#                    hessian_approximation = limited-memory            7
#                                 max_iter = 100                       1
#                              output_file = /home/fenics/shared/templates/RES_OPT/solution_V=0.46499999999999997_w=0.7000000000000001.txt      1
#                              print_level = 6                         2
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.9, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:    10201
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Hessian approximation will be done in the space of all 10201 x variables.
#
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Scaling parameter for objective function = 1.000000e+00
# objective scaling factor = 1
# No x scaling provided
# No c scaling provided
# No d scaling provided
# Moved initial values of x sufficiently inside the bounds.
# Moved initial values of s sufficiently inside the bounds.
# MUMPS used permuting_scaling 5 and pivot_order 5.
#            scaling will be 77.
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Least square estimates max(y_c) = 0.000000e+00, max(y_d) = 9.999010e-01
# Total number of variables............................:    10201
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:    10201
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        1
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 1.262e-16 (tol = 1.000e-07) r (rel) = 1.274e-12 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
# **************************************************
# *** Update HessianMatrix for Iteration 0:
# **************************************************
#
# Limited-Memory approximation started; store data at current iterate.
#
#
# **************************************************
# *** Summary of Iteration: 0:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.1291139e-05 1.92e-01 1.00e-04   0.0 0.00e+00    -  0.00e+00 0.00e+00   0 y
#
# **************************************************
# *** Beginning Iteration 0 from the following point:
# **************************************************
#
# Current barrier parameter mu = 1.0000000000000000e+00
# Current fraction-to-the-boundary parameter tau = 0.0000000000000000e+00
#
# ||curr_x||_inf   = 9.9000000989999992e-01
# ||curr_s||_inf   = 9.9999900000000003e-03
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 9.9990102813181236e-01
# ||curr_z_L||_inf = 1.0000000000000000e+00
# ||curr_z_U||_inf = 1.0000000000000000e+00
# ||curr_v_L||_inf = 1.0000000000000000e+00
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 0:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.1291139049861166e-05    3.1291139049861166e-05
# Dual infeasibility......:   1.0002157279132007e-04    1.0002157279132007e-04
# Constraint violation....:   1.9158469670465467e-01    1.9158469670465467e-01
# Complementarity.........:   9.9000001999999998e-01    9.9000001999999998e-01
# Overall NLP error.......:   9.9000001999999998e-01    9.9000001999999998e-01
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 0:
# **************************************************
#
# Setting mu_max to 4.999760e+02.
# Staying in free mu mode.
# The current filter has 1 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 8.050304e-03
# Barrier parameter mu computed by oracle is 4.024959e-03
# Barrier parameter mu after safeguards is 4.024959e-03
# Barrier Parameter: 4.024959e-03
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 0:
# **************************************************
#
# residual_ratio = 9.054992e-17
# Factorization successful.
# residual_ratio = 1.088427e-17
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 0:
# **************************************************
#
# --> Starting line search in iteration 0 <--
# Mu has changed in line search - resetting watchdog counters.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 3.735209E-11
# Starting checks for alpha (primal) = 4.95e-02
# trial_max is initialized to 1.000000e+04
# trial_min is initialized to 1.000000e-04
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 1.234e-16 (tol = 1.000e-07) r (rel) = 1.246e-12 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 4.947049e-02:
#   New values of barrier function     =  8.9864964913938692e+01  (reference  8.9982769016923655e+01):
#   New values of constraint violation =  1.9161220299481868e-01  (reference  2.0158469670465468e-01):
# Checking sufficient reduction...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
# **************************************************
# *** Update HessianMatrix for Iteration 1:
# **************************************************
#
# In limited-memory update, s_new_max is 1.942115e-04
# Limited-Memory test for skipping:
#      s^Ty = 2.013361e-10 snrm = 1.148640e-02 ynrm = 3.565888e-08
#      Perform the update.
# sigma (for B0) is 1.525997e-06
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 1:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    1  3.1305008e-05 1.92e-01 1.84e+01  -2.4 2.00e-01    -  9.97e-01 4.95e-02f  1  sigma=8.05e-03 qf=13
#
# **************************************************
# *** Beginning Iteration 1 from the following point:
# **************************************************
#
# Current barrier parameter mu = 4.0249589625782406e-03
# Current fraction-to-the-boundary parameter tau = 9.8999999999999999e-01
#
# ||curr_x||_inf   = 9.8980629343559801e-01
# ||curr_s||_inf   = 9.9990000000001189e-05
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 1.9603471015758003e+00
# ||curr_z_L||_inf = 1.6775303773664318e-02
# ||curr_z_U||_inf = 1.3782194978984585e-02
# ||curr_v_L||_inf = 2.0358167741006586e+01
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 1:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.1305007738621721e-05    3.1305007738621721e-05
# Dual infeasibility......:   1.8397820639430787e+01    1.8397820639430787e+01
# Constraint violation....:   1.9151220299481869e-01    1.9151220299481869e-01
# Complementarity.........:   1.0794397625702678e-02    1.0794397625702678e-02
# Overall NLP error.......:   1.8397820639430787e+01    1.8397820639430787e+01
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 1:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 2 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 7.221955e-01
# Barrier parameter mu computed by oracle is 3.944683e-03
# Barrier parameter mu after safeguards is 3.944683e-03
# Barrier Parameter: 3.944683e-03
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 1:
# **************************************************
#
# residual_ratio = 1.871754e-16
# Factorization successful.
# residual_ratio = 3.655770e-19
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 1:
# **************************************************
#
# --> Starting line search in iteration 1 <--
# Mu has changed in line search - resetting watchdog counters.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 4.476295E-13
# Starting checks for alpha (primal) = 1.00e+00
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 9.497e-17 (tol = 1.000e-07) r (rel) = 9.584e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 1.000000e+00:
#   New values of barrier function     =  5.8935678372526432e+01  (reference  8.8072644477691867e+01):
#   New values of constraint violation =  1.0015317568334847e-17  (reference  1.9161220299481868e-01):
# Checking sufficient reduction...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 2:
# **************************************************
#
# In limited-memory update, s_new_max is 3.133979e-01
# Limited-Memory test for skipping:
#      s^Ty = 2.881299e-04 snrm = 2.338709e+01 ynrm = 2.786478e-05
#      Perform the update.
# sigma (for B0) is 5.267883e-07
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 2:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    2  1.6423180e-04 0.00e+00 7.62e-06  -2.4 3.13e-01    -  1.00e+00 1.00e+00f  1 Nhj  sigma=7.22e-01 qf=12y
#
# **************************************************
# *** Beginning Iteration 2 from the following point:
# **************************************************
#
# Current barrier parameter mu = 3.9446827534500243e-03
# Current fraction-to-the-boundary parameter tau = 9.8999999999999999e-01
#
# ||curr_x||_inf   = 7.0664440795274430e-01
# ||curr_s||_inf   = 1.5609722090370359e-06
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 5.9485173944882270e+01
# ||curr_z_L||_inf = 1.2433097975660872e-02
# ||curr_z_U||_inf = 7.3705706019989471e-03
# ||curr_v_L||_inf = 5.9485174118026009e+01
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 2:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.6423179760735959e-04    1.6423179760735959e-04
# Dual infeasibility......:   7.6179342205868680e-06    7.6179342205868680e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   5.0308408315038328e-03    5.0308408315038328e-03
# Overall NLP error.......:   5.0308408315038328e-03    5.0308408315038328e-03
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 2:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 3 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 1.000000e-06
# Barrier parameter mu computed by oracle is 3.328371e-09
# Barrier parameter mu after safeguards is 3.328371e-09
# Barrier Parameter: 3.328371e-09
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 2:
# **************************************************
#
# residual_ratio = 1.194419e-16
# Factorization successful.
# residual_ratio = 2.916062e-20
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 2:
# **************************************************
#
# --> Starting line search in iteration 2 <--
# Mu has changed in line search - resetting watchdog counters.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 1.696076E-19
# Starting checks for alpha (primal) = 1.00e+00
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 9.209e-17 (tol = 1.000e-07) r (rel) = 9.294e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 1.000000e+00:
#   New values of barrier function     =  2.1392979487698993e-04  (reference  2.1395931622318956e-04):
#   New values of constraint violation =  9.4568899220337684e-17  (reference  1.0015317568334847e-17):
# Checking Armijo Condition...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 3:
# **************************************************
#
# In limited-memory update, s_new_max is 3.797951e-04
# Limited-Memory test for skipping:
#      s^Ty = 4.393266e-12 snrm = 1.022136e-03 ynrm = 1.426152e-08
#      Perform the update.
# sigma (for B0) is 4.205039e-06
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 3:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    3  1.6420227e-04 0.00e+00 4.37e-08  -8.5 3.80e-04    -  9.94e-01 1.00e+00f  1  sigma=1.00e-06 qf=13y A
#
# **************************************************
# *** Beginning Iteration 3 from the following point:
# **************************************************
#
# Current barrier parameter mu = 3.3283714906996769e-09
# Current fraction-to-the-boundary parameter tau = 9.9496915916849615e-01
#
# ||curr_x||_inf   = 7.0664651101889497e-01
# ||curr_s||_inf   = 1.5609851237554430e-06
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 3.4129246039805439e-01
# ||curr_z_L||_inf = 7.1134874391587388e-05
# ||curr_z_U||_inf = 4.2084253630355825e-05
# ||curr_v_L||_inf = 3.4129246141171876e-01
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 3:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.6420227492742277e-04    1.6420227492742277e-04
# Dual infeasibility......:   4.3667897999913091e-08    4.3667897999913091e-08
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.8807631903968174e-05    2.8807631903968174e-05
# Overall NLP error.......:   2.8807631903968174e-05    2.8807631903968174e-05
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 3:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 4 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 2.107435e-02
# Barrier parameter mu computed by oracle is 4.006017e-07
# Barrier parameter mu after safeguards is 4.006017e-07
# Barrier Parameter: 4.006017e-07
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 3:
# **************************************************
#
# residual_ratio = 3.285451e-16
# Factorization successful.
# residual_ratio = 1.592328e-18
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 3:
# **************************************************
#
# --> Starting line search in iteration 3 <--
# Mu has changed in line search - resetting watchdog counters.
# Storing current iterate as backup acceptable point.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 2.282415E-21
# Starting checks for alpha (primal) = 1.00e+00
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 9.066e-17 (tol = 1.000e-07) r (rel) = 9.149e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 1.000000e+00:
#   New values of barrier function     =  6.1292425147212413e-03  (reference  6.1493906505157951e-03):
#   New values of constraint violation =  2.9080589255018816e-16  (reference  9.4568899220337684e-17):
# Checking Armijo Condition...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 4:
# **************************************************
#
# In limited-memory update, s_new_max is 6.523908e-02
# Limited-Memory test for skipping:
#      s^Ty = 3.663660e-07 snrm = 3.827576e-01 ynrm = 2.569522e-06
#      Perform the update.
# sigma (for B0) is 2.500734e-06
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 4:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    4  1.5942419e-04 0.00e+00 2.44e-07  -6.4 6.52e-02    -  9.09e-01 1.00e+00f  1  sigma=2.11e-02 qf=12y A
#
# **************************************************
# *** Beginning Iteration 4 from the following point:
# **************************************************
#
# Current barrier parameter mu = 4.0060172668934505e-07
# Current fraction-to-the-boundary parameter tau = 9.9997119236809606e-01
#
# ||curr_x||_inf   = 7.0166618422460680e-01
# ||curr_s||_inf   = 2.7307347905548178e-06
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 3.1948945576051158e-02
# ||curr_z_L||_inf = 7.1885990321538771e-06
# ||curr_z_U||_inf = 5.6370778129593539e-06
# ||curr_v_L||_inf = 3.1948941147635468e-02
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 4:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5942419123487765e-04    1.5942419123487765e-04
# Dual infeasibility......:   2.4363729714067880e-07    2.4363729714067880e-07
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   3.2774469950759069e-06    3.2774469950759069e-06
# Overall NLP error.......:   3.2774469950759069e-06    3.2774469950759069e-06
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 4:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 5 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 2.467349e-01
# Barrier parameter mu computed by oracle is 5.179459e-07
# Barrier parameter mu after safeguards is 5.179459e-07
# Barrier Parameter: 5.179459e-07
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 4:
# **************************************************
#
# residual_ratio = 7.930554e-17
# Factorization successful.
# residual_ratio = 1.281862e-17
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 4:
# **************************************************
#
# --> Starting line search in iteration 4 <--
# Mu has changed in line search - resetting watchdog counters.
# Storing current iterate as backup acceptable point.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 6.298558E-22
# Starting checks for alpha (primal) = 7.85e-01
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 4.867e-17 (tol = 1.000e-07) r (rel) = 4.912e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 7.854801e-01:
#   New values of barrier function     =  7.7348131058316803e-03  (reference  7.8779201687874476e-03):
#   New values of constraint violation =  8.7468010265268070e-17  (reference  2.9080589255018816e-16):
# Checking Armijo Condition...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 5:
# **************************************************
#
# In limited-memory update, s_new_max is 3.790990e-01
# Limited-Memory test for skipping:
#      s^Ty = 2.008761e-05 snrm = 2.848049e+00 ynrm = 1.463898e-05
#      Perform the update.
# sigma (for B0) is 2.476472e-06
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 5:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    5  1.3872124e-04 0.00e+00 2.83e-06  -6.3 4.83e-01    -  7.86e-01 7.85e-01f  1  sigma=2.47e-01 qf=12y A
#
# **************************************************
# *** Beginning Iteration 5 from the following point:
# **************************************************
#
# Current barrier parameter mu = 5.1794588185165684e-07
# Current fraction-to-the-boundary parameter tau = 9.9999672255300487e-01
#
# ||curr_x||_inf   = 9.9999876751919159e-01
# ||curr_s||_inf   = 1.5372056037322963e-05
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 7.9165293979788255e-03
# ||curr_z_L||_inf = 2.3539075945280791e-06
# ||curr_z_U||_inf = 6.5461868819462021e-06
# ||curr_v_L||_inf = 7.9165306571983042e-03
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 5:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.3872124103541560e-04    1.3872124103541560e-04
# Dual infeasibility......:   2.8297448668987618e-06    2.8297448668987618e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.3731776059845865e-06    1.3731776059845865e-06
# Overall NLP error.......:   2.8297448668987618e-06    2.8297448668987618e-06
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 5:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 4 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 2.417654e-01
# Barrier parameter mu computed by oracle is 2.071601e-07
# Barrier parameter mu after safeguards is 2.071601e-07
# Barrier Parameter: 2.071601e-07
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 5:
# **************************************************
#
# residual_ratio = 1.854309e-16
# Factorization successful.
# residual_ratio = 7.491613e-18
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 5:
# **************************************************
#
# --> Starting line search in iteration 5 <--
# Mu has changed in line search - resetting watchdog counters.
# Storing current iterate as backup acceptable point.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 8.216447E-24
# Starting checks for alpha (primal) = 1.00e+00
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 3.610e-17 (tol = 1.000e-07) r (rel) = 3.643e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 1.000000e+00:
#   New values of barrier function     =  3.1416508022607706e-03  (reference  3.1768901807393800e-03):
#   New values of constraint violation =  1.1358373009501266e-16  (reference  8.7468010265268070e-17):
# Checking Armijo Condition...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 6:
# **************************************************
#
# In limited-memory update, s_new_max is 3.771792e-01
# Limited-Memory test for skipping:
#      s^Ty = 1.536429e-05 snrm = 2.287138e+00 ynrm = 9.920295e-06
#      Perform the update.
# sigma (for B0) is 2.937161e-06
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 6:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    6  1.2789146e-04 0.00e+00 9.71e-07  -6.7 3.77e-01    -  1.00e+00 1.00e+00f  1  sigma=2.42e-01 qf=12y A
#
# **************************************************
# *** Beginning Iteration 6 from the following point:
# **************************************************
#
# Current barrier parameter mu = 2.0716009214976612e-07
# Current fraction-to-the-boundary parameter tau = 9.9999717025513313e-01
#
# ||curr_x||_inf   = 9.6835346742530082e-01
# ||curr_s||_inf   = 3.8222782252519746e-05
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 1.7072874474715527e-03
# ||curr_z_L||_inf = 5.3011257359211922e-07
# ||curr_z_U||_inf = 3.2546175848661822e-06
# ||curr_v_L||_inf = 1.7072891597972777e-03
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 6:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2789145694996296e-04    1.2789145694996296e-04
# Dual infeasibility......:   9.7069250825626538e-07    9.7069250825626538e-07
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   4.5311956264071538e-07    4.5311956264071538e-07
# Overall NLP error.......:   9.7069250825626538e-07    9.7069250825626538e-07
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 6:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 5 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 4.810506e-05
# Barrier parameter mu computed by oracle is 1.000000e-11
# Barrier parameter mu after safeguards is 1.000000e-11
# Barrier Parameter: 1.000000e-11
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 6:
# **************************************************
#
# residual_ratio = 1.300940e-17
# Factorization successful.
# residual_ratio = 2.540991e-18
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 6:
# **************************************************
#
# --> Starting line search in iteration 6 <--
# Mu has changed in line search - resetting watchdog counters.
# Storing current iterate as backup acceptable point.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 1.496327E-21
# Starting checks for alpha (primal) = 7.13e-01
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 3.113e-17 (tol = 1.000e-07) r (rel) = 3.142e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 7.134118e-01:
#   New values of barrier function     =  1.0517476937931086e-04  (reference  1.2803693667600652e-04):
#   New values of constraint violation =  4.6495332540683054e-17  (reference  1.1358373009501266e-16):
# Checking Armijo Condition...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 7:
# **************************************************
#
# In limited-memory update, s_new_max is 2.064219e-01
# Limited-Memory test for skipping:
#      s^Ty = 8.115336e-06 snrm = 2.647604e+00 ynrm = 5.722273e-06
#      Perform the update.
# sigma (for B0) is 1.157711e-06
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 7:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    7  1.0502685e-04 0.00e+00 2.35e-06 -11.0 2.89e-01    -  6.69e-01 7.13e-01f  1  sigma=4.81e-05 qf=13y A
#
# **************************************************
# *** Beginning Iteration 7 from the following point:
# **************************************************
#
# Current barrier parameter mu = 9.9999999999999994e-12
# Current fraction-to-the-boundary parameter tau = 9.9999902930749174e-01
#
# ||curr_x||_inf   = 9.9999997928093820e-01
# ||curr_s||_inf   = 2.0824495818019128e-05
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 1.2937514446237947e-03
# ||curr_z_L||_inf = 2.2177397984234773e-07
# ||curr_z_U||_inf = 4.1296474519691070e-06
# ||curr_v_L||_inf = 1.2937727957638976e-03
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 7:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.0502684535307238e-04    1.0502684535307238e-04
# Dual infeasibility......:   2.3489424126162069e-06    2.3489424126162069e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.9150321590709338e-07    1.9150321590709338e-07
# Overall NLP error.......:   2.3489424126162069e-06    2.3489424126162069e-06
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 7:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 4 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 2.418662e-01
# Barrier parameter mu computed by oracle is 1.667335e-08
# Barrier parameter mu after safeguards is 1.667335e-08
# Barrier Parameter: 1.667335e-08
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 7:
# **************************************************
#
# residual_ratio = 1.190287e-15
# Factorization successful.
# residual_ratio = 3.448642e-17
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 7:
# **************************************************
#
# --> Starting line search in iteration 7 <--
# Mu has changed in line search - resetting watchdog counters.
# Storing current iterate as backup acceptable point.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 1.049654E-23
# Starting checks for alpha (primal) = 1.00e+00
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 3.265e-17 (tol = 1.000e-07) r (rel) = 3.295e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 1.000000e+00:
#   New values of barrier function     =  3.3446697375069705e-04  (reference  3.5166575020702782e-04):
#   New values of constraint violation =  1.9724009209763638e-16  (reference  4.6495332540683054e-17):
# Checking Armijo Condition...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 8:
# **************************************************
#
# In limited-memory update, s_new_max is 1.782658e-01
# Limited-Memory test for skipping:
#      s^Ty = 9.479179e-06 snrm = 4.123526e+00 ynrm = 4.121241e-06
#      Perform the update.
# sigma (for B0) is 5.574850e-07
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 8:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    8  8.0829948e-05 0.00e+00 5.59e-07  -7.8 1.78e-01    -  9.23e-01 1.00e+00f  1  sigma=2.42e-01 qf=12y A
#
# **************************************************
# *** Beginning Iteration 8 from the following point:
# **************************************************
#
# Current barrier parameter mu = 1.6673349903032249e-08
# Current fraction-to-the-boundary parameter tau = 9.9999765105758742e-01
#
# ||curr_x||_inf   = 9.9596250791802643e-01
# ||curr_s||_inf   = 2.0918451589327194e-05
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 8.3292940206118008e-04
# ||curr_z_L||_inf = 1.0322452315307614e-07
# ||curr_z_U||_inf = 1.3547097983076634e-06
# ||curr_v_L||_inf = 8.3294130497805715e-04
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 8:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.0829948458172130e-05    8.0829948458172130e-05
# Dual infeasibility......:   5.5890823646415656e-07    5.5890823646415656e-07
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   5.6960556283713679e-08    5.6960556283713679e-08
# Overall NLP error.......:   5.5890823646415656e-07    5.5890823646415656e-07
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 8:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 5 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 3.443586e-01
# Barrier parameter mu computed by oracle is 7.256014e-09
# Barrier parameter mu after safeguards is 7.256014e-09
# Barrier Parameter: 7.256014e-09
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 8:
# **************************************************
#
# residual_ratio = 2.110719e-15
# Factorization successful.
# residual_ratio = 7.777647e-17
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 8:
# **************************************************
#
# --> Starting line search in iteration 8 <--
# Mu has changed in line search - resetting watchdog counters.
# Storing current iterate as backup acceptable point.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 3.882063E-21
# Starting checks for alpha (primal) = 6.06e-01
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 3.593e-17 (tol = 1.000e-07) r (rel) = 3.626e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 6.058155e-01:
#   New values of barrier function     =  1.7923102473648767e-04  (reference  1.9120930785779955e-04):
#   New values of constraint violation =  1.1517954016763976e-16  (reference  1.9724009209763638e-16):
# Checking Armijo Condition...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 9:
# **************************************************
#
# In limited-memory update, s_new_max is 1.514036e-01
# Limited-Memory test for skipping:
#      s^Ty = 5.074102e-06 snrm = 4.102459e+00 ynrm = 2.476650e-06
#      Perform the update.
# sigma (for B0) is 3.014884e-07
# Number of successive iterations with skipping: 0
#
#
# **************************************************
# *** Summary of Iteration: 9:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    9  6.4425795e-05 0.00e+00 3.03e-07  -8.1 2.50e-01    -  9.58e-01 6.06e-01f  1  sigma=3.44e-01 qf=12y A
#
# **************************************************
# *** Beginning Iteration 9 from the following point:
# **************************************************
#
# Current barrier parameter mu = 7.2560135067818842e-09
# Current fraction-to-the-boundary parameter tau = 9.9999944109176353e-01
#
# ||curr_x||_inf   = 9.9999992891647060e-01
# ||curr_s||_inf   = 1.8477499093168265e-05
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 5.2090576149927575e-04
# ||curr_z_L||_inf = 6.0717778763959493e-08
# ||curr_z_U||_inf = 1.2932715707234222e-06
# ||curr_v_L||_inf = 5.2090703542283755e-04
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 9:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.4425795292288616e-05    6.4425795292288616e-05
# Dual infeasibility......:   3.0316739495532675e-07    3.0316739495532675e-07
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.4470614947069286e-08    2.4470614947069286e-08
# Overall NLP error.......:   3.0316739495532675e-07    3.0316739495532675e-07
#
#
#
#
# **************************************************
# *** Update Barrier Parameter for Iteration 9:
# **************************************************
#
# Staying in free mu mode.
# The current filter has 5 entries.
# Solving the Primal Dual System for the affine step
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Factorization successful.
# Factorization successful.
# Number of trial factorizations performed: 1
# Perturbation parameters: delta_x=0.000000e+00 delta_s=0.000000e+00
#                          delta_c=0.000000e+00 delta_d=0.000000e+00
# Solving the Primal Dual System for the centering step
# Factorization successful.
# Sigma = 4.389463e-01
# Barrier parameter mu computed by oracle is 3.738308e-09
# Barrier parameter mu after safeguards is 3.738308e-09
# Barrier Parameter: 3.738308e-09
#
# **************************************************
# *** Solving the Primal Dual System for Iteration 9:
# **************************************************
#
# residual_ratio = 1.261074e-16
# Factorization successful.
# residual_ratio = 3.041485e-17
#
# **************************************************
# *** Finding Acceptable Trial Point for Iteration 9:
# **************************************************
#
# --> Starting line search in iteration 9 <--
# Mu has changed in line search - resetting watchdog counters.
# Storing current iterate as backup acceptable point.
# The current filter has 0 entries.
# minimal step size ALPHA_MIN = 1.641380E-22
# Starting checks for alpha (primal) = 6.23e-01
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.909e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 4.358e-17 (tol = 1.000e-07) r (rel) = 4.398e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Checking acceptability for trial step size alpha_primal_test= 6.231586e-01:
#   New values of barrier function     =  1.1224609942366884e-04  (reference  1.2357360557471825e-04):
#   New values of constraint violation =  1.0570971181733668e-18  (reference  1.1517954016763976e-16):
# Checking Armijo Condition...
# Succeeded...
# Checking filter acceptability...
# Succeeded...
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
#
# **************************************************
# *** Update HessianMatrix for Iteration 10:
# **************************************************
#
# In limited-memory update, s_new_max is 2.799952e-01
# Limited-Memory test for skipping:
#      s^Ty = 6.297017e-06 snrm = 5.591010e+00 ynrm = 2.200428e-06
#      Perform the update.
# sigma (for B0) is 2.014440e-07
# ...
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
#
# **************************************************
# *** Summary of Iteration: 0:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.8085247e-05 0.00e+00 1.00e-04   0.0 0.00e+00    -  0.00e+00 0.00e+00   0 y
#
# **************************************************
# *** Beginning Iteration 0 from the following point:
# **************************************************
#
# Current barrier parameter mu = 1.0000000000000000e+00
# Current fraction-to-the-boundary parameter tau = 0.0000000000000000e+00
#
# ||curr_x||_inf   = 9.9000000989999992e-01
# ||curr_s||_inf   = 3.6215044866940660e-02
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 9.9990102126954894e-01
# ||curr_z_L||_inf = 1.0000000000000000e+00
# ||curr_z_U||_inf = 1.0000000000000000e+00
# ||curr_v_L||_inf = 1.0000000000000000e+00
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 0:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.8085246999624045e-05    2.8085246999624045e-05
# Dual infeasibility......:   9.9993202404280446e-05    9.9993202404280446e-05
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.9000001989999997e-01    9.9000001989999997e-01
# Overall NLP error.......:   9.9000001989999997e-01    9.9000001989999997e-01
#
#
#
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.8085246999624045e-05    2.8085246999624045e-05
# Dual infeasibility......:   9.9993202404280446e-05    9.9993202404280446e-05
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.9000001989999997e-01    9.9000001989999997e-01
# Overall NLP error.......:   9.9000001989999997e-01    9.9000001989999997e-01
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 1
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 1
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.207
# Total CPU secs in NLP function evaluations           =      0.117
#
# EXIT: Maximum Number of Iterations Exceeded.
# Optimization complete: v=0.5, w=0.5
# rm: cannot remove '/home/fenics/shared/templates/RES_SIM/TEMP*': No such file or directory
# Obj_GAN_output: 0.00001870489980 Obj_GAN_optimized: 0.00002808524700
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.906e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 4.087e-17 (tol = 1.000e-07) r (rel) = 4.126e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
# List of options:
#
#                                     Name   Value                # times used
#                           acceptable_tol = 0.001                     1
#                    hessian_approximation = limited-memory            7
#                                 max_iter = 0                         1
#                              print_level = 6                         2
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.9, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:    10201
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Hessian approximation will be done in the space of all 10201 x variables.
#
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Scaling parameter for objective function = 1.000000e+00
# objective scaling factor = 1
# No x scaling provided
# No c scaling provided
# No d scaling provided
# Moved initial values of x sufficiently inside the bounds.
# Initial values of s sufficiently inside the bounds.
# MUMPS used permuting_scaling 5 and pivot_order 5.
#            scaling will be 77.
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Least square estimates max(y_c) = 0.000000e+00, max(y_d) = 9.999010e-01
# Total number of variables............................:    10201
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:    10201
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        1
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.906e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 3.972e-17 (tol = 1.000e-07) r (rel) = 4.009e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
#
# **************************************************
# *** Summary of Iteration: 0:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.6004937e-05 0.00e+00 1.00e-04   0.0 0.00e+00    -  0.00e+00 0.00e+00   0 y
#
# **************************************************
# *** Beginning Iteration 0 from the following point:
# **************************************************
#
# Current barrier parameter mu = 1.0000000000000000e+00
# Current fraction-to-the-boundary parameter tau = 0.0000000000000000e+00
#
# ||curr_x||_inf   = 9.9000000989999992e-01
# ||curr_s||_inf   = 3.6437043124447399e-02
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 9.9990101881934057e-01
# ||curr_z_L||_inf = 1.0000000000000000e+00
# ||curr_z_U||_inf = 1.0000000000000000e+00
# ||curr_v_L||_inf = 1.0000000000000000e+00
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 0:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.6004936565297460e-05    2.6004936565297460e-05
# Dual infeasibility......:   9.9995794539564642e-05    9.9995794539564642e-05
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.9000001989999997e-01    9.9000001989999997e-01
# Overall NLP error.......:   9.9000001989999997e-01    9.9000001989999997e-01
#
#
#
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.6004936565297460e-05    2.6004936565297460e-05
# Dual infeasibility......:   9.9995794539564642e-05    9.9995794539564642e-05
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.9000001989999997e-01    9.9000001989999997e-01
# Overall NLP error.......:   9.9000001989999997e-01    9.9000001989999997e-01
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 1
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 1
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.202
# Total CPU secs in NLP function evaluations           =      0.114
#
# EXIT: Maximum Number of Iterations Exceeded.
# Optimization complete: v=0.5, w=0.5
# rm: cannot remove '/home/fenics/shared/templates/RES_SIM/TEMP*': No such file or directory
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.906e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 4.222e-17 (tol = 1.000e-07) r (rel) = 4.262e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
# List of options:
#
#                                     Name   Value                # times used
#                           acceptable_tol = 0.001                     1
#                    hessian_approximation = limited-memory            7
#                                 max_iter = 0                         1
#                              print_level = 6                         2
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.9, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:    10201
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Hessian approximation will be done in the space of all 10201 x variables.
#
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Scaling parameter for objective function = 1.000000e+00
# objective scaling factor = 1
# No x scaling provided
# No c scaling provided
# No d scaling provided
# Moved initial values of x sufficiently inside the bounds.
# Initial values of s sufficiently inside the bounds.
# MUMPS used permuting_scaling 5 and pivot_order 5.
#            scaling will be 77.
# Number of doubles for MUMPS to hold factorization (INFO(9)) = 20406
# Number of integers for MUMPS to hold factorization (INFO(10)) = 244848
# Factorization successful.
# Least square estimates max(y_c) = 0.000000e+00, max(y_d) = 9.999010e-01
# Total number of variables............................:    10201
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:    10201
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        1
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.906e-05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 4.071e-17 (tol = 1.000e-07) r (rel) = 4.109e-13 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
#
# **************************************************
# *** Summary of Iteration: 0:
# **************************************************
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.8766115e-05 0.00e+00 1.00e-04   0.0 0.00e+00    -  0.00e+00 0.00e+00   0 y
#
# **************************************************
# *** Beginning Iteration 0 from the following point:
# **************************************************
#
# Current barrier parameter mu = 1.0000000000000000e+00
# Current fraction-to-the-boundary parameter tau = 0.0000000000000000e+00
#
# ||curr_x||_inf   = 9.9000000989999992e-01
# ||curr_s||_inf   = 3.7543249210728991e-02
# ||curr_y_c||_inf = 0.0000000000000000e+00
# ||curr_y_d||_inf = 9.9990102213154852e-01
# ||curr_z_L||_inf = 1.0000000000000000e+00
# ||curr_z_U||_inf = 1.0000000000000000e+00
# ||curr_v_L||_inf = 1.0000000000000000e+00
# ||curr_v_U||_inf = 0.0000000000000000e+00
#
#
# ***Current NLP Values for Iteration 0:
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.8766114741597800e-05    2.8766114741597800e-05
# Dual infeasibility......:   1.0001130348946674e-04    1.0001130348946674e-04
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.9000001989999997e-01    9.9000001989999997e-01
# Overall NLP error.......:   9.9000001989999997e-01    9.9000001989999997e-01
#
#
#
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.8766114741597800e-05    2.8766114741597800e-05
# Dual infeasibility......:   1.0001130348946674e-04    1.0001130348946674e-04
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.9000001989999997e-01    9.9000001989999997e-01
# Overall NLP error.......:   9.9000001989999997e-01    9.9000001989999997e-01
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 1
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 1
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.199
# Total CPU secs in NLP function evaluations           =      0.111
#
# EXIT: Maximum Number of Iterations Exceeded.
# Optimization complete: v=0.5, w=0.5
# rm: cannot remove '/home/fenics/shared/templates/RES_SIM/TEMP*': No such file or directory
# Obj_Dataset: 0.00002600493657 Obj_Dataset_optimized: 0.00002876611474

# %%
# Metrics
print('MMD:', metrics.mmd(gen_designs_np, np.array(test_ds['optimal_design'])[selected_indices]), sigma=sigma)
print('DPP:', metrics.dpp_diversity(gen_designs_np), sigma=sigma)
# Out:
# MMD: 0.40000000298023225
# DPP: 1.0000050000099996

# %%
# Compute the average instnataneous and cumulative optimality gap for the dataset of generated designs
COG_list = []
IOG_list = []
FOG_list = []
for i in range(n_samples):
    opt_design, opt_history = problem.optimize(gen_designs_np[i], sampled_conditions[i])
    reference_optimum = problem.simulate(np.array(test_ds['optimal_design'][selected_indices[i]]))
    opt_history_gaps = metrics.optimality_gap(opt_history, reference_optimum)

    IOG_list.append(opt_history_gaps[0])
    COG_list.append(np.sum(opt_history_gaps))
    FOG_list.append(opt_history_gaps[-1])


average_IOG = np.mean(IOG_list)
average_COG = np.mean(COG_list)
average_FOG = np.mean(FOG_list)

print('Average COG:', average_COG, 'Average IOG:', average_IOG, 'Average FOG:', average_FOG)
# Out:
# Average COG: 113975081.49582541 Average IOG: 113974649.45676644 Average FOG: 0.7800931512747518

# %%
metrics = metrics.metrics(problem, gen_designs_np, np.array(test_ds['optimal_design'])[selected_indices], sampled_conditions, sigma=sigma)
metrics
